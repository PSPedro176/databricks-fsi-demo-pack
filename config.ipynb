# %%
# Databricks notebook source
# All parameters are injected by the DAB job via base_parameters.
# When running interactively, fill the widgets at the top of the notebook.

dbutils.widgets.text("catalog", "", "Catalog name")
dbutils.widgets.text("schema", "", "Schema name")
dbutils.widgets.text("volume_name", "", "Volume name")

catalog = dbutils.widgets.get("catalog")
schema = dbName = db = dbutils.widgets.get("schema")
volume_name = dbutils.widgets.get("volume_name")

assert catalog, "Parameter 'catalog' is required. Set it in the job task or fill the widget."
assert schema, "Parameter 'schema' is required."

print(f"Config loaded: {catalog}.{schema} (volume: {volume_name})")
